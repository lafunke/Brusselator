# %%
import dolfinx
import pymor
from pymor.bindings.fenicsx import FenicsxVectorSpace

print(f"FEniCSx version: {dolfinx.__version__}")
print(f"pyMOR version: {pymor.__version__}")
print("Both are installed and ready for the Brusselator!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import dolfinx
#       2 import pymor
#       3 from pymor.bindings.fenicsx import FenicsxVectorSpace
#
# ModuleNotFoundError: No module named 'dolfinx'
