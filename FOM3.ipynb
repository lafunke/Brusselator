# %%
import dolfinx
from mpi4py import MPI
from dolfinx import mesh

# 1. Create a 1D mesh (the spatial domain for our Brusselator)
# We divide the interval [0, 1] into 20 segments
domain = mesh.create_unit_interval(MPI.COMM_WORLD, 20)

print(f"FEniCSx version {dolfinx.__version__} is live!")
print(f"Mesh created with {domain.topology.index_map(0).size_global} vertices.")

import pymor
print(f"pyMOR version {pymor.__version__} is ready for reduction.")
