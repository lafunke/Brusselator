# %%
import pymor               
from pymor.basic import * 
import matplotlib.pyplot as plt

print(f"pyMOR is ready! Version: {pymor.__version__}")
# Out:
# pyMOR is ready! Version: 2025.1.2

# %%
from pymor.models.examples import heat_equation_example
fom = heat_equation_example(grid_intervals=50, nt=50)
parameter_space = fom.parameters.space(1, 101)
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))

# %%
print(fom.products.keys())
# Out:
# dict_keys(['h1', 'h1_semi', 'l2', 'h1_0', 'h1_0_semi', 'l2_0'])

# %%
print(fom.parameters)
# Out:
# {top: 1}

# %%
# create std snapshots (heat)
number_sample_mus = 5
sample_mus = parameter_space.sample_uniformly(number_sample_mus) # 5 mus and we compute solution for every 50 timesteps

std_snapshots = fom.solution_space.empty()
for mu in sample_mus:

    U = fom.solve(mu)
    
    std_snapshots.append(U)

len(std_snapshots), sample_mus
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
# (255,
#  [Mu({'top': array([1.])}),
#   Mu({'top': array([26.])}),
#   Mu({'top': array([51.])}),
#   Mu({'top': array([76.])}),
#   Mu({'top': array([101.])})])

# %%
# create curly U snapshots (heat)

import numpy as np

U_curly = fom.solution_space.empty()      
   
# parameters
L = len(sample_mus) - 1  # parameter steps
M = fom.time_stepper.nt # time steps
N = (L + 1)*(M + 1)  # total number elements curly_U
dt = fom.T / M    # distant one time step
d_alpha = sample_mus[1]['top'] - sample_mus[0]['top'] # distant between first and second parameter

all_solutions = [fom.solve(mu) for mu in sample_mus]  # compute FOM solutions for all mu

for l in range(L + 1):
        
    vector = all_solutions[l][0].copy() # copy keeps all_solutions as it was
    vector *= np.sqrt(N) 
    U_curly.append(vector) # here we add starting values for every mu: u_h^{\alpha_l}(t_0^l) 

for j in range(1, M + 1):

    diff_t = (all_solutions[0][j] - all_solutions[0][j-1]) * (1.0 / dt)  
    diff_t *= np.sqrt(L + 1)
    U_curly.append(diff_t)  # D^t u_h^{\alpha_0}(t_j^0)

for l in range(1, L + 1):
    for j in range(1, M + 1):
            
        # (u_h^l(t_j^l) - u_h^{l-1}(t_j^{l-1})) over (\Delta \alpha)
        u_alpha_diff_j = (all_solutions[l][j] - all_solutions[l-1][j]) * (1.0 / d_alpha)  
        
        # (u_h^l(t_{j-1}^l) - u_h^{l-1}(t_{j-1}^{l-1})) over (\Delta \alpha)
        u_alpha_diff_j_minus_1 = (all_solutions[l][j-1] - all_solutions[l-1][j-1]) * (1.0 / d_alpha) 
        
        mixed_diff = (u_alpha_diff_j - u_alpha_diff_j_minus_1) * (1.0 / dt)  # take D^t
        U_curly.append(mixed_diff)  # here we add all other differences to U_curly

len(U_curly), N, M, dt, d_alpha
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
# (255, 255, 50, 0.02, array([25.]))

# %%
# just plot one solution of fom to check
U = fom.solve(50.0)
fom.visualize(U);
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))

# %%
# POD with U_curly 
r_curly_U = 50

from pymor.algorithms.pod import pod
U_pod_basis, U_pod_singular_values = pod(U_curly,
                                     product=fom.products['h1_0_semi'],
                                     modes=r_curly_U
                                    )
len(U_pod_basis)
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
# 28

# %%
# POD with std 
r_std = 50

from pymor.algorithms.pod import pod
std_pod_basis, std_pod_singular_values = pod(std_snapshots,
                                     product=fom.products['h1_0_semi'],
                                     modes=r_std  
                                    )
len(std_pod_basis)
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
# 35

# %%
print(f"Anzahl der Snapshots: {len(std_snapshots)}")
print(f"Anzahl der POD-Modi_std: {len(std_pod_basis)}")
print(f"Anzahl der POD-Modi_U: {len(U_pod_basis)}")
# Out:
# Anzahl der Snapshots: 255
# Anzahl der POD-Modi_std: 35
# Anzahl der POD-Modi_U: 28

# %%
# construct ROM using curly U 

from pymor.reductors.parabolic import ParabolicRBReductor

reductor_U = ParabolicRBReductor(
       fom=fom,
       RB=U_pod_basis,
       product=fom.h1_0_semi_product,
       coercivity_estimator=None,
       check_orthonormality=None,
       check_tol=None
   )
rom_U = reductor_U.reduce()
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))

# %%
# construct ROM using std 

from pymor.reductors.parabolic import ParabolicRBReductor

reductor_std = ParabolicRBReductor(
       fom=fom,
       RB=std_pod_basis,
       product=fom.h1_0_semi_product,
       coercivity_estimator=None,
       check_orthonormality=None,
       check_tol=None
   )
rom_std = reductor_std.reduce()
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))

# %%
# test my ROMs (if its u_..., we already have a specific parameter) (heat) for one parameter

test_mu = parameter_space.sample_randomly(1)[0] 

u_rom_std = rom_std.solve(test_mu) # solve rom for this mu in low dim
u_rec_std = reductor_std.reconstruct(u_rom_std) # back to high dim

u_rom_U = rom_U.solve(test_mu) # solve rom for this mu in low dim
u_rec_U = reductor_U.reconstruct(u_rom_U) # back to high dim

u_fom = fom.solve(test_mu)

fom.visualize((u_fom, u_rec_std, u_rec_U), 
                     legend=("Full Order", "Standard ROM", "Curly U ROM"));
test_mu
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
# Mu({'top': array([86.85979199])})

# %%
# compute both ROMs f
test_samples = parameter_space.sample_uniformly(10)

errors_std = []
errors_U = []

for mu in test_samples:
    
    u_fom = fom.solve(mu)  # compute fom solution
    
    u_rom_std = rom_std.solve(mu)
    u_rec_std = reductor_std.reconstruct(u_rom_std)   # compute std ROM solution
    

    u_rom_U = rom_U.solve(mu)
    u_rec_U = reductor_U.reconstruct(u_rom_U)   # compute curly U ROM solution

    
    err_std = (u_fom - u_rec_std).norm(fom.h1_0_semi_product)  # \norm{(u_h - u_r^std)} over all time steps
    err_U = (u_fom - u_rec_U).norm(fom.h1_0_semi_product)      # \norm{(u_h - u_r^U)} over all time steps

    max_err_over_time_std = np.max(err_std)                  # max_{t} \norm{(u_h - u_r^std)} over all time steps
    max_err_over_time_U = np.max(err_U)                    # max_{t} \norm{(u_h - u_r^U)} over all time steps

    min_err_over_time_std = np.min(err_std)                  # max_{t} \norm{(u_h - u_r^std)} over all time steps
    min_err_over_time_U = np.min(err_U)                    # max_{t} \norm{(u_h - u_r^U)} over all time steps
    
    errors_std.append(max_err_over_time_std)  
    errors_U.append(max_err_over_time_U)    
    
    #print(mu)
    #print(max_err_over_time_std)
    #print(max_err_over_time_U)

    print(f"{mu['top'][0]:15.2f} | {max_err_over_time_std} | {max_err_over_time_U} | {min_err_over_time_std} | {min_err_over_time_U}")
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
#            1.00 | 4.793274927486524e-06 | 1.1926642624547548e-05 | 1.9543643256381755e-13 | 2.5184125182988052e-11
#           12.11 | 0.012526313374257124 | 0.018214254428786682 | 1.9543643256381755e-13 | 2.5184125182988052e-11
#           23.22 | 0.0004189880761774698 | 0.0011672587487880724 | 1.9543643256381755e-13 | 2.5184125182988052e-11
#           34.33 | 0.00022828149817762954 | 0.0009472468613580496 | 1.9543643256381755e-13 | 2.5184125182988052e-11
#           45.44 | 5.962232714554777e-05 | 0.0008967417646409446 | 1.9543643256381755e-13 | 2.5184125182988052e-11
#           56.56 | 2.7047061592144498e-05 | 0.0008146576736990754 | 1.9543643256381755e-13 | 2.5184125182988052e-11
#           67.67 | 2.5055244453618145e-05 | 0.0008649796674117585 | 1.9543643256381755e-13 | 2.5184125182988052e-11
#           78.78 | 1.401585630420332e-05 | 0.0009900487269140688 | 1.9543643256381755e-13 | 2.5184125182988052e-11
#           89.89 | 2.0248101752814355e-05 | 0.0011649237880529413 | 1.9543643256381755e-13 | 2.5184125182988052e-11
#          101.00 | 1.196696869438571e-05 | 0.0013757787599590343 | 1.9543643256381755e-13 | 2.5184125182988052e-11

# %%
# for the error anylysis: (u_h - u_r) = (u_h - Pr(u_h)) + (Pr(u_h) - u_r))
# compute Pr(u_h), the projection of the FOM solution onto U_pod_basis

coeffs = fom.products['h1_0_semi'].apply2(U_pod_basis, u_fom) 

u_projected = U_pod_basis.lincomb(coeffs) # proj onto U ROM

error_proj = (u_fom - u_projected).norm(fom.products['h1_0_semi']) # (u_h - Pr(u_h))

error_rom_U = (u_fom - u_rec_U).norm(fom.products['h1_0_semi'])  # (Pr(u_h) - u_r)

# for std
coeffs = fom.products['h1_0_semi'].apply2(std_pod_basis, u_fom) 

std_u_projected = std_pod_basis.lincomb(coeffs) # proj onto std ROM

std_error_proj = (u_fom - std_u_projected).norm(fom.products['h1_0_semi']) # (u_h - Pr(u_h))

std_error_rom = (u_fom - u_rec_std).norm(fom.products['h1_0_semi'])  # (Pr(u_h) - u_r)



# for error analysis we also wanna set the eigenvalue tail

# we start with the std case
energies_std = std_pod_singular_values**2

total_energy = np.sum(energies_std) # the whole sum
# To get the true TOTAL energy of all snapshots
captured_energy = np.sum(energies_std[:r_std])
captured_energy, total_energy
# Out:
# (np.float64(229906.70069664883), np.float64(229906.70069664883))

# %%
# visualisation of u_h, Pr(u_h), u_N (obtained std ROM), u_N (obtained curlyU ROM) 

fom.visualize(
    (u_fom, u_projected, u_rec_U, u_rec_std), 
    legend=("Full Order", "Proj", "Curly U ROM", "Standard ROM")
);

# %%
import matplotlib.pyplot as plt
errors1 = (u_fom - u_rec_U).norm(fom.products['h1_0_semi'])
errors2 = (u_fom - u_rec_std).norm(fom.products['h1_0_semi'])

plt.plot(errors1, label='Curly U ROM Error') 
plt.plot(errors2, label='Standard ROM Error') 
plt.yscale('log') 
plt.legend()     
plt.show()

# %%
import matplotlib.pyplot as plt
errors1 = (u_fom - u_rec_U).norm(fom.products['l2'])
errors2 = (u_fom - u_rec_std).norm(fom.products['l2'])

plt.plot(errors1, label='Curly U ROM Error') 
plt.plot(errors2, label='Standard ROM Error') 
plt.yscale('log') 
plt.legend()     
plt.show()

# %%
# schleife über r modes für std rom (immer 5 r höher), fehler dann max t und H01 norm, für einen festen parameter

#testmu = parameter_space.sample_randomly(1)[0]
#print(f"Test-Parameter für Plot: {test_mu['top'][0]}")
testmu=50
u_fom = fom.solve(testmu)

max_r = len(std_pod_basis)
r_values = range(1, max_r + 1, 5) 
errors_std = []
errors_U = []

for r in r_values:

        print(f"start{r}")
 
        rom_r_std = reductor_std.reduce(dims={'RB': r})  # construct ROM with r modes
        u_rom_std = rom_r_std.solve(testmu) # solve for testmu
        u_rec_std = reductor_std.reconstruct(u_rom_std) # reconstruct to high dim
    
       
        err = np.max((u_fom - u_rec_std).norm(fom.h1_0_semi_product))   # consider error max{t}\norm{(u_h - u_r^std)}
        errors_std.append(err)
        print(f"{r}done")

plt.figure(figsize=(10, 6))
plt.semilogy(r_values, errors_std, 'b-o', label='std ROM error')
plt.xlabel('modes r')
plt.ylabel('max_{t} error of (H1-Seminorm)')
plt.title(f'Convergence std ROM (Parameter top={testmu})')
plt.grid(True, which="both", ls="-")
plt.legend()
plt.show()
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
# start1
# 1done
# start6
# 6done
# start11
# 11done
# start16
# 16done
# start21
# 21done
# start26
# 26done
# start31
# 31done

# %%
# schleife über r modes für U rom (immer 5 r höher), fehler dann max t und H01 norm, für einen festen parameter

#testmu = parameter_space.sample_randomly(1)[0]
#print(f"Test-Parameter für Plot: {testmu['top'][0]}")
testmu=50
u_fom = fom.solve(testmu)

max_r_U = len(U_pod_basis)
r_values_U = range(1, max_r_U + 1, 5)

errors_std = []
errors_U = []

for r in r_values_U:

        print(f"start{r}")

        rom_r_U = reductor_U.reduce(dims={'RB': r}) # construct ROM with r modes
        u_rom_U = rom_r_U.solve(testmu) # solve for testmu
        u_rec_U = reductor_U.reconstruct(u_rom_U) # reconstruct to high dim
    
       
        err = np.max((u_fom - u_rec_U).norm(fom.h1_0_semi_product))   # consider error max{t}\norm{(u_h - u_r^std)}
        errors_U.append(err)


plt.figure(figsize=(10, 6))
plt.semilogy(r_values_U, errors_U, 'b-o', label='U ROM error')
plt.xlabel('modes r')
plt.ylabel('max_{t} error of (H1-Seminorm)')
plt.title(f'Convergence U ROM (Parameter={testmu})')
plt.grid(True, which="both", ls="-")
plt.legend()
plt.show()
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
# start1
# start6
# start11
# start16
# start21
# start26

# %%
# schleife über r modes für U ROM UND STD ROM (immer 5 r höher), fehler dann max t und H01 norm, für einen festen parameter

#testmu = parameter_space.sample_randomly(1)[0]
#print(f"Test-Parameter für Plot: {testmu['top'][0]}")
testmu=50
u_fom = fom.solve(testmu)

testmu=50
u_fom = fom.solve(testmu)

max_r_U = len(U_pod_basis)
max_r_std = len(std_pod_basis)
min_r = min(max_r_U, max_r_std)

r_values = range(1, min_r + 1, 5)

errors_std = []
errors_U = []

for r in r_values:

        print(f"start{r}")
    
        rom_r_U = reductor_U.reduce(dims={'RB': r}) # construct ROM with r modes
        u_rom_U = rom_r_U.solve(testmu) # solve for testmu
        u_rec_U = reductor_U.reconstruct(u_rom_U) # reconstruct to high dim
       
        err = np.max((u_fom - u_rec_U).norm(fom.h1_0_semi_product))   # consider error max{t}\norm{(u_h - u_r^std)}
        errors_U.append(err)

        rom_r_std = reductor_std.reduce(dims={'RB': r}) # construct ROM with r modes
        u_rom_std = rom_r_std.solve(testmu) # solve for testmu
        u_rec_std = reductor_std.reconstruct(u_rom_std) # reconstruct to high dim

        err = np.max((u_fom - u_rec_std).norm(fom.h1_0_semi_product))   # consider error max{t}\norm{(u_h - u_r^std)}
        errors_std.append(err)
# Out:
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
# start1
# start6
# start11
# start16
# start21
# start26

# %%
plt.figure(figsize=(10, 6))
plt.semilogy(r_values, errors_std, 'b-o', label='std ROM')
plt.semilogy(r_values, errors_U, 'r-s', label='Curly U ROM')
plt.xlabel('modes r', fontsize=12)
plt.ylabel('max_{t} error over (H1-Seminorm)', fontsize=12)
plt.title(f'Convergence comparison std vs. U ROM (Parameter={testmu})', fontsize=14)
plt.grid(True, which="both", ls="--", alpha=0.7)
plt.legend(fontsize=11)
plt.show()

# %%
# now we need to fo this for several parameters 'top' and then consider min, max and average
# compute fom solution for errors

number_of_test_mus = 10
test_mus = parameter_space.sample_uniformly(number_of_test_mus)

all_fom_solutions = []

for mu_idx, mu in enumerate(test_mus):  # loop over parameters (save index) 
    print(f"Compute fom for {mu_idx+1}/{number_of_test_mus}: {mu['top'][0]}")
    u_fom = fom.solve(mu) 

    all_fom_solutions.append(u_fom)
# Out:
# Compute fom for 1/10: 1.0
# Accordion(children=(HTML(value='', layout=Layout(height='16em', width='100%')),), titles=('Log Output',))
# Compute fom for 2/10: 12.11111111111111
# Compute fom for 3/10: 23.22222222222222
# Compute fom for 4/10: 34.33333333333333
# Compute fom for 5/10: 45.44444444444444
# Compute fom for 6/10: 56.55555555555556
# Compute fom for 7/10: 67.66666666666666
# Compute fom for 8/10: 78.77777777777777
# Compute fom for 9/10: 89.88888888888889
# Compute fom for 10/10: 101.0

# %%
# std case 

max_r_std = len(std_pod_basis)
r_values_std = range(1, max_r_std + 1, 5)

all_errors_std = np.zeros((number_of_test_mus, len(r_values_std))) # to access min, max, average


for mu_idx, mu in enumerate(test_mus):  # loop over parameters (save index) 
    #print(f"mu loop for {mu_idx+1}/{number_of_test_mus}: {mu['top'][0]}")
    
    for r_idx, r in enumerate(r_values_std):   # loop over modes 
        
        u_fom = all_fom_solutions[mu_idx]  # access fom solution
        
        rom_r_std = reductor_std.reduce(dims={'RB': r}) # construct ROM with r modes
        u_rom_std = rom_r_std.solve(mu)
        u_rec_std = reductor_std.reconstruct(u_rom_std) # reconstruct to high dim
        
        err = np.max((u_fom - u_rec_std).norm(fom.h1_0_semi_product))
        all_errors_std[mu_idx, r_idx] = err                       # add err to exactly this index


min_err_std = np.min(all_errors_std, axis=0)  # take min over all parameters
max_err_std = np.max(all_errors_std, axis=0)
mean_err_std = np.mean(all_errors_std, axis=0)

min_err_std, max_err_std, mean_err_std
# Out:
# (array([1.20823718e+02, 1.79296036e+00, 1.72288440e-01, 1.12333350e-02,
#         2.36176377e-03, 2.21768345e-04, 4.69240182e-05]),
#  array([1.20823718e+02, 2.43016909e+00, 3.94364622e-01, 1.67536829e-01,
#         3.66849466e-02, 1.89390068e-02, 1.54355367e-02]),
#  array([1.20823718e+02, 2.00183384e+00, 2.33757598e-01, 3.50858066e-02,
#         6.80367384e-03, 2.27974961e-03, 1.67293336e-03]))

# %%
# plot std

plt.figure(figsize=(10, 6))
plt.fill_between(r_values_std, min_err_std, max_err_std, color='b', alpha=0.2)

plt.semilogy(r_values_std, mean_err_std, 'b-o', linewidth=2, label='mean error')
plt.semilogy(r_values_std, max_err_std, 'r--', alpha=0.7, label='max error')
plt.semilogy(r_values_std, min_err_std, 'g--', alpha=0.7, label='min error')

plt.xlabel('modes r')
plt.ylabel('ROM error in (H1-Seminorm), max over t')
plt.title(f'Std ROM over {number_of_test_mus} Parameter')
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend()
plt.show()

# %%
# U case 

max_r_U = len(U_pod_basis)
r_values_U = range(1, max_r_U + 1, 5)

all_errors_U = np.zeros((number_of_test_mus, len(r_values_U))) # to access min, max, average


for mu_idx, mu in enumerate(test_mus):  # loop over parameters (save index) 
    #print(f"mu loop for {mu_idx+1}/{number_of_test_mus}: {mu['top'][0]}")
    
    for r_idx, r in enumerate(r_values_U):   # loop over modes 
        
        u_fom = all_fom_solutions[mu_idx]  # access fom solution
        
        rom_r_U = reductor_U.reduce(dims={'RB': r}) # construct ROM with r modes
        u_rom_U = rom_r_U.solve(mu) 
        u_rec_U = reductor_U.reconstruct(u_rom_U) # reconstruct to high dim
        
        err = np.max((u_fom - u_rec_U).norm(fom.h1_0_semi_product))
        all_errors_U[mu_idx, r_idx] = err                       # add err to exactly this index


min_err_U = np.min(all_errors_U, axis=0)  # take min over all parameters
max_err_U = np.max(all_errors_U, axis=0)
mean_err_U = np.mean(all_errors_U, axis=0)

min_err_U, max_err_U, mean_err_U
# Out:
# (array([2.33424921e+01, 1.49167528e-01, 2.00184153e-02, 1.61610173e-03,
#         2.18505006e-04, 1.22141003e-05]),
#  array([4.48033792e+01, 1.63802313e+01, 1.28926858e+00, 2.01460150e-01,
#         7.31447233e-02, 2.03721349e-02]),
#  array([2.82870307e+01, 1.31533751e+01, 8.39551316e-01, 1.52965437e-01,
#         1.86202407e-02, 3.75724511e-03]))

# %%
# plot U

plt.figure(figsize=(10, 6))
plt.fill_between(r_values_U, min_err_U, max_err_U, color='b', alpha=0.2)

plt.semilogy(r_values_U, mean_err_U, 'b-o', linewidth=2, label='mean error')
plt.semilogy(r_values_U, max_err_U, 'r--', alpha=0.7, label='max error')
plt.semilogy(r_values_U, min_err_U, 'g--', alpha=0.7, label='min error')

plt.xlabel('modes r')
plt.ylabel('ROM error in (H1-Seminorm), max over t')
plt.title(f'U ROM over {number_of_test_mus} Parameter')
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend()
plt.show()

# %%
# plot für beide

plt.figure(figsize=(10, 6))

plt.fill_between(r_values, min_err_U, max_err_U, color='b', alpha=0.15)
plt.semilogy(r_values, mean_err_U, 'b-o', linewidth=2, label='mean error (U)')
plt.semilogy(r_values, max_err_U, 'b--', alpha=0.6)
plt.semilogy(r_values, min_err_U, 'b:', alpha=0.6)

plt.fill_between(r_values_std, min_err_std, max_err_std, color='r', alpha=0.15)
plt.semilogy(r_values_std, mean_err_std, 'r-s', linewidth=2, label='mean error (std)')
plt.semilogy(r_values_std, max_err_std, 'r--', alpha=0.6)
plt.semilogy(r_values_std, min_err_std, 'r:', alpha=0.6)

plt.xlabel('modes r')
plt.ylabel(r'ROM error in ($H^1$-Seminorm), max over t')
plt.title(f'both ROMs over {number_of_test_mus} Parameter')
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend()
plt.show()


# mean ROM error over 10 uniformly dist parameters
# max error over 50 time steps
# H1 seminorm
# 255 snapshots (5 parameters * 50 timesteps)
# POD takes r modes

# %%
# L2
# std case 

max_r_std = len(std_pod_basis)
r_values_std = range(1, max_r_std + 1, 5)

all_errors_std = np.zeros((number_of_test_mus, len(r_values_std))) # to access min, max, average


for mu_idx, mu in enumerate(test_mus):  # loop over parameters (save index) 
    #print(f"mu loop for {mu_idx+1}/{number_of_test_mus}: {mu['top'][0]}")
    
    for r_idx, r in enumerate(r_values_std):   # loop over modes 
        
        u_fom = all_fom_solutions[mu_idx]  # access fom solution
        
        rom_r_std = reductor_std.reduce(dims={'RB': r}) # construct ROM with r modes
        u_rom_std = rom_r_std.solve(mu)
        u_rec_std = reductor_std.reconstruct(u_rom_std) # reconstruct to high dim
        
        err = np.max((u_fom - u_rec_std).norm(fom.l2_product))
        all_errors_std[mu_idx, r_idx] = err                       # add err to exactly this index


min_err_std = np.min(all_errors_std, axis=0)  # take min over all parameters
max_err_std = np.max(all_errors_std, axis=0)
mean_err_std = np.mean(all_errors_std, axis=0)

min_err_std, max_err_std, mean_err_std
# Out:
# (array([2.33091937e+00, 1.18546529e-01, 1.10978106e-02, 7.12584681e-04,
#         1.31939850e-04, 9.47005423e-06, 1.94545928e-06]),
#  array([2.91716263e+00, 1.55835895e-01, 2.16310540e-02, 1.33742872e-02,
#         2.88957622e-03, 8.09140988e-04, 5.62314337e-04]),
#  array([2.38954370e+00, 1.39859687e-01, 1.36630492e-02, 2.52439066e-03,
#         5.35171070e-04, 1.03009475e-04, 6.24002142e-05]))

# %%
# L2
# U case 

max_r_U = len(U_pod_basis)
r_values_U = range(1, max_r_U + 1, 5)

all_errors_U = np.zeros((number_of_test_mus, len(r_values_U))) # to access min, max, average


for mu_idx, mu in enumerate(test_mus):  # loop over parameters (save index) 
    #print(f"mu loop for {mu_idx+1}/{number_of_test_mus}: {mu['top'][0]}")
    
    for r_idx, r in enumerate(r_values_U):   # loop over modes 
        
        u_fom = all_fom_solutions[mu_idx]  # access fom solution
        
        rom_r_U = reductor_U.reduce(dims={'RB': r}) # construct ROM with r modes
        u_rom_U = rom_r_U.solve(mu) 
        u_rec_U = reductor_U.reconstruct(u_rom_U) # reconstruct to high dim
        
        err = np.max((u_fom - u_rec_U).norm(fom.l2_product))
        all_errors_U[mu_idx, r_idx] = err                       # add err to exactly this index


min_err_U = np.min(all_errors_U, axis=0)  # take min over all parameters
max_err_U = np.max(all_errors_U, axis=0)
mean_err_U = np.mean(all_errors_U, axis=0)

min_err_U, max_err_U, mean_err_U
# Out:
# (array([4.41957092e+00, 1.06264653e-02, 1.47803442e-03, 1.05244671e-04,
#         1.15775743e-05, 4.57723646e-07]),
#  array([1.18271338e+01, 2.23922829e+00, 9.79730378e-02, 1.24775622e-02,
#         3.52364010e-03, 1.17984524e-03]),
#  array([6.45265551e+00, 1.86434188e+00, 5.68039186e-02, 1.06166650e-02,
#         1.24751385e-03, 2.47922272e-04]))

# %%
# plot für beide

plt.figure(figsize=(10, 6))

plt.fill_between(r_values, min_err_U, max_err_U, color='b', alpha=0.15)
plt.semilogy(r_values, mean_err_U, 'b-o', linewidth=2, label='mean error (U)')
plt.semilogy(r_values, max_err_U, 'b--', alpha=0.6)
plt.semilogy(r_values, min_err_U, 'b:', alpha=0.6)

plt.fill_between(r_values_std, min_err_std, max_err_std, color='r', alpha=0.15)
plt.semilogy(r_values_std, mean_err_std, 'r-s', linewidth=2, label='mean error (std)')
plt.semilogy(r_values_std, max_err_std, 'r--', alpha=0.6)
plt.semilogy(r_values_std, min_err_std, 'r:', alpha=0.6)

plt.xlabel('modes r')
plt.ylabel(r'ROM error in ($L^2$-norm), max over t')
plt.title(f'both ROMs over {number_of_test_mus} Parameter')
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend()
plt.show()


# mean ROM error over 10 uniformly dist parameters
# max error over 50 time steps
# L2 norm
# 255 snapshots (5 parameters * 50 timesteps)
# POD takes r modes
