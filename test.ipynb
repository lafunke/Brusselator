# %%
import sys
print(sys.executable)
# Out:
# C:\Users\laraf\anaconda3\python.exe

# %%
# !pip install pymor[full]

# %%
import pymor
pymor.__version__
# Out:
# '2025.1.2'

# %%
pip install 'pymor[gui]'
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: "'pymor[gui]'": Expected package name at the start of dependency specifier
#     'pymor[gui]'
#     ^
