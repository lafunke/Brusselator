# %%
import numpy as np
import matplotlib.pyplot as plt

from pymor.vectorarrays.numpy import NumpyVectorSpace
from pymor.algorithms.pod import pod


snapshots_raw = np.load('my_brusselator_snapshots.npy')
print(f"Datei erfolgreich geladen. Shape: {snapshots_raw.shape}")

space = NumpyVectorSpace(snapshots_raw.shape[1])
std_snapshots = space.from_numpy(snapshots_raw.T)

print(f"Erfolg: {len(std_snapshots)} Snapshots sind jetzt wieder pyMOR-Vektoren.")
# Out:
# Datei erfolgreich geladen. Shape: (202, 303)
# Erfolg: 202 Snapshots sind jetzt wieder pyMOR-Vektoren.

# %%
r_std = 5

from pymor.algorithms.pod import pod
std_pod_basis, std_pod_singular_values = pod(std_snapshots,
                                     product=Brusselator_fom.products['h1_0_semi'],
                                     modes=r_std  
                                    )
len(std_pod_basis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 r_std = 5
#       3 from pymor.algorithms.pod import pod
#       4 std_pod_basis, std_pod_singular_values = pod(std_snapshots,
# ----> 5                                      product=Brusselator_fom.products['h1_0_semi'],
#       6                                      modes=r_std
#       7                                     )
#       8 len(std_pod_basis)
#
# NameError: name 'Brusselator_fom' is not defined
